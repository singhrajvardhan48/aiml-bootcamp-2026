# %% [markdown]
# <a href="https://colab.research.google.com/github/singhrajvardhan48/aiml-bootcamp-2026/blob/main/session__16Jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("session4_dummy_students.csv")
print(df)
# Out:
#     student_id    name  age     city  math  science  english  \
# 0          101   Aarav   16   Mumbai    78       84       69
# 1          102    Diya   16    Delhi    91       88       94
# 2          103   Kabir   17  Mathura    55       61       58
# 3          104   Meera   16    Noida    72       79       81
# 4          105   Rohan   17   Mumbai    40       52       47
# 5          106    Sara   16    Delhi    88       93       90
# 6          107  Ishaan   17  Mathura    64       70       66
# 7          108  Ananya   16    Noida    95       92       89
# 8          109  Vivaan   17   Mumbai    48       57       51
# 9          110    Tara   16    Delhi    83       76       85
# 10         111   Arjun   17  Mathura    67       63       72
# 11         112   Nisha   16    Noida    74       81       79
# 12         113     Dev   17   Mumbai    35       45       42
# 13         114   Priya   16    Delhi    89       86       91
# ...

# %%
science_scores = df['science'].to_numpy()
print(science_scores)
print(type(science_scores))
print(science_scores.mean())
# Out:
# [84 88 61 79 52 93 70 92 57 76 63 81 45 86 54 90 69 85 49 73]
# <class 'numpy.ndarray'>
# 72.35

# %%
science_score=df["science"].to_numpy()
math_score=df["math"].to_numpy()
english_score=df["english"].to_numpy()
avg=(math_score.sum()+science_score.sum()+english_score.sum())/3
print(avg )
# Out:
# 1427.0

# %%
filter_1 = df[df['average']>85]
filter_2 = df[df['attendance_percent'] < 75 ]
filter_3 = df[df['city']=='Mathura']
print(filter_1)
print(filter_2)
print(filter_3)
# Out:
#     student_id    name  age   city  math  science  english  \
# 1          102    Diya   16  Delhi    91       88       94
# 5          106    Sara   16  Delhi    88       93       90
# 7          108  Ananya   16  Noida    95       92       89
# 13         114   Priya   16  Delhi    89       86       91
# 15         116    Riya   16  Noida    92       90       96
#
#     attendance_percent  study_hours_per_week  assignments_submitted  \
# 1                   96                    11                     10
# 5                   97                    10                     10
# 7                   94                    12                     10
# 13                  95                    10                     10
# 15                  98                    13                     10
#
#     final_project_score    average result    Average
# 1                    93  91.000000   Pass  91.000000
# 5                    95  90.333333   Pass  90.333333
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("session4_dummy_students.csv")

# Create average column
df["average"] = (df["math"] + df["science"] + df["english"]) / 3

# Create result column
def check_result(avg):
    if avg >= 40:
        return "Pass"
    else:
        return "Fail"

df["result"] = df["average"].apply(check_result)

# Print class average
class_average = df["average"].mean()
print("class average:", class_average)

# Print highest and lowest average
highest_average = df["average"].max()
lowest_average = df["average"].min()

print("highest average:", highest_average)
print("lowest average:", lowest_average)

# Print top student(s)
print("\ntop student:")
top_students = df[df["average"] == highest_average]
print(top_students[["name", "average"]])

# Print students with attendance below 75%
print("\nattendance below 75%:")
low_attendance = df[df["attendance_percent"] < 75]
print(low_attendance[["name", "attendance_percent"]])

# Print students who submitted fewer than 6 assignments
print("\nless than 6 assignments:")
few_assignments = df[df["assignments_submitted"] < 6]
print(few_assignments[["name", "assignments_submitted"]])

# Save final report
df.to_csv("session4_student_report.csv", index=False)

print("\nReport saved as session4_student_report.csv")
# Out:
# class average: 71.35000000000001
# highest average: 92.66666666666667
# lowest average: 40.666666666666664
#
# top student:
#     name    average
# 15  Riya  92.666667
#
# attendance below 75%:
#       name  attendance_percent
# 4    Rohan                  68
# 8   Vivaan                  71
# 12     Dev                  62
# 18    Yash                  66
#
# less than 6 assignments:
#      name  assignments_submitted
# 4   Rohan                      5
# 12    Dev                      4
# 18   Yash                      5
#
# Report saved as session4_student_report.csv
